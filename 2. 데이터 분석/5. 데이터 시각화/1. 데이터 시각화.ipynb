# %% [markdown]
# 아래의 코드는 한글깨짐 현상을 방지하기 위한 설정입니다. 코드 실행하면 한글 설정 완료 됩니다. 세션시작마다 실행한 후, 세션 재시작!

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
import matplotlib.pyplot as plt

# plt.rc('font', family='D2Coding')

# %%
import warnings

warnings.filterwarnings(action='ignore')

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# ---
#
# <br/>
#
# # 데이터 시각화
# 데이터시각화의 기본 모듈은 Matplotlib입니다. 상황에 따라 생성하는 그래프를 살펴보기 위해 가장 먼저 Matplotlib 을 익혀봅니다.
# # Marplotlib 기본 사용법
# Matplotlib은 Python에서 가장 기본이자 강력한 데이터 시각화 라이브러리입니다.
# 특히 matplotlib.pyplot 모듈은  간단한 API를 제공하여, 다양한 유형의 시각화를 손쉽게 구현할 수 있습니다.
# <br/>
#
# - 선 그래프, 막대 그래프, 히스토그램, 산점도, 파이 차트 등 다양한 그래프 제공
# - x축, y축, 눈금, 색상, 범례, 타이틀 등 디테일한 커스터마이징 가능
# - Pandas, NumPy와 함께 사용 시 연동성이 뛰어남
# - 그래프를 이미지 파일로 저장하는 기능도 제공 (plt.savefig())
# <br/>
# <br/>
# <br/>
# 먼저 라이브러리를 불러와 사용해보겠습니다.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# 가장 기본적인 그래프는 선그래프입니다.  선그래프를 그리며, Matplotlib 의 기본 구성을 익혀보세요.
# * plot() 함수를 사용하여 기본적인 선 그래프를 생성한다.
# * marker, linestyle, color 옵션을 이용하여 스타일 지정이 가능하다.
# * xlabel(), ylabel(), title()을 이용하여 그래프에 설명을 추가할 수 있다.

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 50]

# %% [markdown]
# 위에서 생성한 데이터로 아래 옵션에 따라 `plot` 그래프를 그려보세요.
# - 선 종류 : 실선("-")
# - 선 색 : 파랑("b")
# - 선 이름(범례) : "Sample Line"
# - X축 라벨 : "X 축"
# - Y축 라벨 : "Y 축"
# - 그래프 제목 : "Matplotlib 기본 사용 예제"
# - 범례 표시 : O
# - 격자 표시 : O

# %%
# 여기에 코드를 작성해보세요!
plt.plot(x, y, marker="o", linestyle="-", color="orange", label="Sample Line")
plt.xlabel("X 축")
plt.ylabel("Y 축")
plt.title("Matplotlib 기본 사용 예제")
plt.legend()
plt.grid()
plt.show()

# %%
# 모범답안

plt.plot(x, y, marker="o", linestyle="-", color="b", label="Sample Line")
plt.xlabel("X 축")
plt.ylabel("Y 축")
plt.title("Matplotlib 기본 사용 예제")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 히스토그램 (Histogram)
#
# * 데이터를 구간(bins)으로 나누어 빈도수를 막대 형태로 시각화한 그래프입니다.
#
# * 데이터의 **분포 형태(정규분포, 치우침 등)**를 한눈에 파악할 수 있습니다.
#
# * 수치형 변수의 전체적인 분포를 파악할 때 가장 기본적으로 사용하는 도구입니다.
#
# * plt.hist() 또는 sns.histplot()을 사용하여 그릴 수 있습니다.
#
# * 구간 개수(bins)를 조절하면 시각적 해석이 달라질 수 있으므로 주의가 필요합니다.
#
# ![image.png](data:image/png;base64,...)

# %%
data = np.random.randn(1000)  # 정규분포를 따르는 랜덤 데이터 생성

# %% [markdown]
# 위에서 생성한 데이터를 아래 옵션에 따라 히스토그램 그래프로 그려보세요.
# - 구간 수(bin) : 30
# - 막대 색 : 파랑("b")
# - 막대 테두리 색 : 검정("black")
# - 막대 투명도 : 0.7
# - X축 라벨 : "값"
# - Y축 라벨 : "빈도수"
# - 그래프 제목 : "히스토그램 예제"

# %%
# 여기에 코드를 작성해보세요!
plt.hist(data, bins=30, color="skyblue", edgecolor="black", alpha=0.7)
plt.xlabel("값")
plt.ylabel("빈도수")
plt.title("히스토그램 예제")
plt.show()

# %%
# 모범답안

import matplotlib.pyplot as plt

plt.hist(data, bins=30, color="blue", edgecolor="black", alpha=0.7)
plt.xlabel("값")
plt.ylabel("빈도수")
plt.title("히스토그램 예제")
plt.show()

# %% [markdown]
# ##  밀도함수 그래프 (KDE Plot)
# * 데이터 분포를 부드러운 곡선 형태로 표현한 그래프입니다.
#
# * 히스토그램보다 연속적인 분포의 흐름을 잘 보여줍니다.
#
# * 확률밀도함수(Probability Density Function)를 추정한 것으로 해석할 수 있습니다.
#
# * seaborn.kdeplot() 또는 sns.histplot(kde=True)로 그릴 수 있습니다.
#
# * 샘플 수가 적거나 이상치가 많을 경우 왜곡될 수 있어 주의해야 합니다.
#
# ![image.png](data:image/png;base64,...)
#
# 다음과 같은 옵션으로 밀도함수 그래프를 그려보겠습니다.
# (비교를 위해 히스토그램 그래프를 그릴때 사용한 데이터를 그대로 활용하겠습니다.)
#
# - 그림자(그래프의 영역) 채우기 : O
# - 선 색 : 파랑("b")
# - X축 라벨 : "값"
# - Y축 라벨 : "밀도"
# - 그래프 제목 : "밀도 그래프 (Density Plot)"

# %%
# 여기에 코드를 작성해보세요!

import seaborn as sns

sns.kdeplot(data, shade=True, color="black")
plt.xlabel("값")
plt.ylabel("밀도")
plt.title("밀도 그래프 (Density Plot)")
plt.show()

# %%
# 모범답안


import seaborn as sns
import matplotlib.pyplot as plt

sns.kdeplot(data, shade=True, color="blue")
plt.xlabel("값")
plt.ylabel("밀도")
plt.title("밀도 그래프 (Density Plot)")
plt.show()

# %% [markdown]
# ##  박스플롯 (Boxplot)
# * 데이터의 중앙값, 사분위수, 최소/최대값, 이상치를 요약하여 보여주는 그래프입니다.
#
# * 수치형 변수의 분포를 간단하게 비교할 수 있어 그룹별 분석에 효과적입니다.
#
# * 중앙값은 상자 안의 선으로, 이상치는 점으로 표시됩니다.
#
# * plt.boxplot() 또는 sns.boxplot()으로 그릴 수 있습니다.
#
# * 이상치 탐지 및 비교 분석 시 매우 유용한 시각화 도구입니다.
#
# ![image.png](data:image/png;base64,...)

# %%
data = [np.random.randn(100) for _ in range(4)]  # 여러 그룹의 데이터 생성

# %% [markdown]
# 위에서 만든 데이터로 다음 옵션에 따라 `boxplot` 그래프를 그려보세요.
# - 그룹명(label) : "A", "B", "C", "D"
# - X축 라벨 : "그룹"
# - Y축 라벨 : "값"
# - 그래프 제목 : "박스 플롯 예제"

# %%
# 여기에 코드를 작성해보세요!
plt.boxplot(data, labels=["A", "B", "C", "D"])
plt.xlabel("그룹")
plt.ylabel("값")
plt.title("박스 플롯 예제")
plt.show()

# %%
df = data
plt.boxplot(df, labels=["A", "B", "C", "D"])

plt.show()

# %%
# 모범 답안

import matplotlib.pyplot as plt

plt.boxplot(data, labels=["A", "B", "C", "D"])
plt.xlabel("그룹")
plt.ylabel("값")
plt.title("박스 플롯 예제")
plt.show()

# %% [markdown]
# ##  산점도 (Scatter Plot)
# * 두 수치형 변수 간의 관계를 점으로 시각화한 그래프입니다.
#
# * 변수 간 상관관계(양의 상관, 음의 상관, 무상관 등)를 확인할 수 있습니다.
#
# * 데이터 분포의 패턴, 이상치, 군집 등을 직관적으로 파악할 수 있습니다.
#
# * plt.scatter() 또는 sns.scatterplot()으로 작성할 수 있습니다.
#
# ![image.png](data:image/png;base64,...)
#
# 데이터는 다음과 같이 만들겠습니다.
#
# 산점도 데이터
# - X가 0~1 사이의 난수, Y가 $y = 2x + 1 + \text{noise}$를 만족하는 데이터 100개를 생성합니다.
# ($\text{noise}$는 평균 0, 표준편차 0.2를 따르는 정규 분포입니다.)
#
# 회귀선 데이터
# - X는 0과 1 사이의 값, Y는 $y = 2x + 1$를 만족하는 데이터 100개를 생성합니다.
#
# </br>
#
# 위와 같이 만든 데이터를 이용하여 다음 옵션에 맞춰 한 그래프에 산점도와 회귀선을 그려보세요.
#
# 산점도 그래프 옵션
# - 점 색 : 파랑("b")
# - 점 투명도 : 0.5
# - 산점도 라벨 : "데이터 포인트"
#
# 회귀선 옵션
# - 선 색 : 빨강("red")
# - 선 종류 : 점선("--")
# - 선 라벨 : "회귀선: y = 2x + 1"
#
# 그래프 옵션
# - X축 라벨 : "변수 X"
# - y축 라벨 : "변수 Y"
# - 그래프 제목 : "산점도 및 회귀선 예제"

# %%
import matplotlib.pyplot as plt

# X 값 생성 (0 ~ 1 사이의 난수 100개)
x = np.random.rand(100)
# Y 값 생성 (y = 2x + 1 + 랜덤 노이즈)
noise = np.random.normal(loc=0, scale=0.2, size=100) # 평균 0, 표준편차 0.2의 정규분포 노이즈 추가
y = 2 * x + 1 + noise

# 여기에 코드를 작성해보세요!

plt.scatter(x,y,color="blue",alpha=0.5, label="데이터 포인트")

xline = np.linspace(0, 1, 100)
yline = 2 * xline + 1
plt.plot(xline, yline, color="orange", linestyle="--", label="회귀선: y = 2x + 1")

plt.xlabel("VAR_X")
plt.ylabel("VAR_Y")
plt.title("산점도 및 회귀선")
plt.legend()
plt.show()

# %%
# 모범답안

import matplotlib.pyplot as plt

# X 값 생성 (0 ~ 1 사이의 난수 100개)
x = np.random.rand(100)
# Y 값 생성 (y = 2x + 1 + 랜덤 노이즈)
noise = np.random.normal(loc=0, scale=0.2, size=100) # 평균 0, 표준편차 0.2의 정규분포 노이즈 추가
y = 2 * x + 1 + noise

# 산점도 그리기
plt.scatter(x, y, color="blue", alpha=0.5, label="데이터 포인트")

# 회귀선 추가 (y = 2x + 1)
x_line = np.linspace(0, 1, 100) # 0 ~ 1 사이의 100개 점
y_line = 2 * x_line + 1 # y = 2x + 1 함수식
plt.plot(x_line, y_line, color="red", linestyle="--", label="회귀선: y = 2x + 1")

# 그래프 꾸미기
plt.xlabel("변수 X")
plt.ylabel("변수 Y")
plt.title("산점도 및 회귀선 예제")
plt.legend() # 범례 추가
plt.show()

# %% [markdown]
# ## [참고] 페어플롯 (Pair Plot)
# * pairplot은 수치형 변수들 간의 관계를 한 번에 시각화할 수 있는 그래프입니다.
#
# * 모든 변수 쌍에 대해 **산점도(scatter plot)**를 그리고, **대각선에는 각 변수의 분포(히스토그램 또는 KDE)**를 나타냅니다.
#
# * 변수 간 상관관계, 분포의 대칭성, 이상치 등을 시각적으로 탐색할 수 있습니다.
#
# * 범주형 컬럼을 hue로 설정하면 그룹별 분포를 색상으로 구분할 수 있어 더욱 직관적입니다.
#
# * seaborn.pairplot() 함수로 간단하게 구현할 수 있습니다.
#
# ![image.png](data:image/png;base64,...)

# %%
df = sns.load_dataset("iris")  # 아이리스 데이터셋 활용
sns.pairplot(df, hue="species")
plt.show()

# %% [markdown]
# ##  히트맵 (Heatmap)
# * 행과 열로 구성된 값의 크기를 색상으로 표현한 시각화 도구입니다.
#
# * 보통 상관계수 행렬이나 교차표 데이터에 사용됩니다.
#
# * 값이 클수록 진하거나 밝은 색으로 표시되어 한눈에 비교하기 좋습니다.
#
# * sns.heatmap()을 사용하며, annot=True로 수치 표시 가능하게 할 수 있습니다.
#
# * 변수 간 관계 구조를 시각적으로 표현할 때 매우 유용합니다.
#
# ![image.png](data:image/png;base64,...)
#
# `iris` 데이터에서 꽃받침(Sepal) 길이와 꽃잎(Petal) 넓이의 상관관계를 구하고 이를 다음 옵션에 맞춰 `heatmap`으로 그려보세요.
#
# - 값 표시(각 셀) : O
# - 색상 맵 : "coolwarm"
# - 그래프 제목 : "히트맵 예제"

# %%
# 여기에 코드를 작성해보세요!

import seaborn as sns
corr_matrix = df.loc[:, 'sepal_length':"petal_width"].corr()

sns.heatmap(corr_matrix,annot=True, cmap="coolwarm")
plt.title("히트맵 예제")
plt.show()

# %%
# 모범답안

import seaborn as sns

correlation_matrix = df.loc[:, 'sepal_length':'petal_width'].corr() 
# df.corr()이 아닌 df.loc를 쓰는 이유는 범주형 species가 포함되기 때문.

sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("히트맵 예제")
plt.show()

# %% [markdown]
# ## 막대그래프 (Bar Chart)
# * 범주형 데이터의 빈도수나 수치를 비교할 때 사용하는 기본 그래프입니다.
#
# * 각 막대는 하나의 범주를 나타내며, 길이는 해당 수치를 의미합니다.
#
# * 수치형 데이터의 그룹별 비교에 적합하며, 가로/세로 형태 모두 지원됩니다.
#
# * plt.bar(), sns.barplot()을 사용하여 쉽게 그릴 수 있습니다.
#
# * 평균값 또는 집계된 값과 함께 오차막대(error bar)도 표시할 수 있습니다.
# ![image.png](data:image/png;base64,...)

# %%
categories = ["A", "B", "C", "D"]
values = [10, 20, 15, 25]

# %% [markdown]
# 위에서 만든 각 카테고리별 값을 아래 옵션에 맞춰 `bar` 그래프로 그려보세요.
# - 막대 색 : 초록("green")
# - X축 라벨 : "카테고리"
# - Y축 라벨 : "값"
# - 그래프 제목 : "막대 그래프 예제"

# %%
# 여기에 코드를 작성해보세요!

plt.bar(categories, values, color="green")
plt.xlabel("카테고리")
plt.ylabel("값")
plt.title("막대 그래프 예제")
plt.show()

# %%
# 모범답안

import matplotlib.pyplot as plt

plt.bar(categories, values, color="green")
plt.xlabel("카테고리")
plt.ylabel("값")
plt.title("막대 그래프 예제")
plt.show()

# %% [markdown]
# ## [참고] 카운트플롯 (Count Plot)
# * 범주형 변수의 빈도수(건수)를 막대그래프로 시각화한 그래프입니다.
#
# * 각 막대의 길이는 해당 범주가 얼마나 자주 등장하는지를 나타냅니다.
#
# * sns.countplot()을 사용하며, x, hue 옵션으로 세부 조정 가능
#
# * 막대 길이로 직접적인 수량 비교가 가능해 파이차트보다 해석이 직관적입니다.
#
# * 범주형 데이터의 분포를 빠르게 파악하고 비교할 때 매우 유용합니다.
# ![image.png](data:image/png;base64,...)

# %%
df = pd.DataFrame({"카테고리": np.random.choice(["A", "B", "C", "D"], size=100)})

sns.countplot(x="카테고리", data=df)
plt.title("카운트 플롯 예제")
plt.show()

# %% [markdown]
# ## [참고] 파이차트 (Pie Chart)
# * 전체 중에서 각 항목이 차지하는 비율을 원형으로 시각화한 그래프입니다.
#
# * 조각의 크기는 각 범주의 상대적 비중(%)을 나타냅니다.
#
# * 범주 수가 적을 때 사용하면 효과적이며, 시각적으로 한눈에 비교할 수 있습니다.
#
# * plt.pie()로 쉽게 그릴 수 있으며, autopct 옵션으로 퍼센트 표시 가능
#
# * 단점: 범주가 많거나 수치 차이가 적을 경우 해석이 어려움
#
# ![image.png](data:image/png;base64,...)

# %%
sizes = [30, 20, 40, 10]
labels = ["A", "B", "C", "D"]

# %% [markdown]
# 위에서 만든 데이터를 다음 옵션에 따라 `pie` 그래프로 그려보세요.
# - 조각 라벨 : ["A", "B", "C", "D"] (labels)
# - 조각 라벨 형식 : 소숫점 1자리까지 나타내고 %로 표시("%1.1f%%")
# - 조각 색 : ["red", "blue", "green", "yellow"]
# - 그래프 제목 : "파이 차트 예제"

# %%
# 여기에 코드를 작성해보세요!

plt.pie(sizes, labels=labels, autopct="%1.1f%%")
plt.title("파이 차트 예제")
plt.show()

# %%
# 모범답안

import matplotlib.pyplot as plt

plt.pie(sizes, labels=labels, autopct="%1.1f%%", colors=["red", "blue", "green", "yellow"])
plt.title("파이 차트 예제")
plt.show()

# %% [markdown]
# ## 모자이크 플롯 (Mosaic Plot)
# * 두 개 이상의 범주형 변수 간 관계를 면적 비율로 시각화한 그래프입니다.
#
# * 사각형의 크기는 각 범주 조합의 상대적 빈도수를 나타냅니다.
#
# * 범주형 변수 간의 독립성이나 연관성을 시각적으로 해석할 수 있습니다.
#
# * statsmodels.graphics.mosaicplot을 사용해 생성합니다.
#
# ![image.png](data:image/png;base64,...)

# %%
from statsmodels.graphics.mosaicplot import mosaic

# 예제 데이터 생성 (성별과 구매 여부)
data = {
    '성별': ['남', '여', '남', '여', '남', '여', '남', '남', '여', '여'],
    '구매여부': ['Y', 'N', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'N']
}
df = pd.DataFrame(data)

# %% [markdown]
# 위 데이터에서 성별 구매여부에 대해 교차표를 생성하고 이를 모자이크 플롯으로 그려보세요.

# %%
# 여기에 코드를 작성해보세요!

cross_tab = pd.crosstab(df["성별"], df['구매여부'])

plt.figure(figsize=(6,5))
mosaic(cross_tab.stack())
plt.title("성별과 구매여부 관계")
plt.show()

# %%
# 모범답안

import matplotlib.pyplot as plt
import pandas as pd

# 교차표 생성
cross_tab = pd.crosstab(df['성별'], df['구매여부'])

# 모자이크 플롯 그리기
plt.figure(figsize=(6, 5))
mosaic(cross_tab.stack())
plt.title("성별과 구매여부 모자이크 플롯")
plt.show()

# %% [markdown]
# ## 시계열 데이터 시각화
# 시간에 따른 변화를 나타내는 데이터로, 선 그래프(line chart) 를 주로 사용합니다.
#
# ![image.png](data:image/png;base64,...)

# %%
dates = pd.date_range(start="2024-01-01", periods=100)
values = np.cumsum(np.random.randn(100))  # 랜덤 누적 합계

# %% [markdown]
# 위에서 생성한 시계열 데이터를 아래 옵션에 따라 plot 그래프로 그려보세요.
# - 선 종류 : 실선("-")
# - 선 색 : 파랑("b")
# - 마커 종류 : 원형 마커("o")
# - X축 라벨 : "날짜"
# - Y축 라벨 : "값"
# - 그래프 제목 : "시계열 데이터 시각화"
# - X축 눈금 : 45도 회전

# %%
# 여기에 코드를 작성해보세요!
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(dates, values, marker="x")
plt.show()

# %%
# 모범답안

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(dates, values, linestyle="-", marker="o", color="blue")
plt.xlabel("날짜")
plt.ylabel("값")
plt.title("시계열 데이터 시각화")
plt.xticks(rotation=45)
plt.show()
